// %%
import * as mod from "https://deno.land/std@0.213.0/dotenv/mod.ts";
const keys = await mod.load({export:true}) // read API key from .env

// %%
import{
    Document,
    VectorStoreIndex,
    SimpleDirectoryReader
} from "npm:llamaindex@0.1.8"

// %%
import { load } from "https://deno.land/std@0.221.0/dotenv/mod.ts";

// %%
const documents = await new SimpleDirectoryReader()
    .loadData({directoryPath: "./data"})

// %%
console.log(documents[0]["text"])
// Out:
// I started this decade as a first-year college student fresh out of high school. I was 17, didn’t have a job, didn’t have any industry connections, and really didn’t know shit. And now you’re reading my blog! I would have been proud.
// I’ve told bits and pieces of my story on different podcasts. Now feels like an appropriate time to write down the parts that were most memorable to me.
// Every person’s story is unique and not directly reproducible. I’ve benefited immensely from the privilege of being born in an upper middle class family and looking like a typical coder stereotype. People took chances on me. Still, I hope that sharing my story can be helpful to compare our experiences. Even if our circumstances are too different, at least you might find some of it entertaining.
// 2010
// ...

// %%
const index = await VectorStoreIndex.fromDocuments(documents)

// %%
console.log(index)
// Out:
// VectorStoreIndex {
//   serviceContext: {
//     llm: OpenAI {
//       apiKey: undefined,
//       model: "gpt-3.5-turbo",
//       temperature: 0.1,
//       topP: 1,
//       maxTokens: undefined,
//       maxRetries: 10,
//       timeout: 60000,
//       additionalChatOptions: undefined,
//       additionalSessionOptions: undefined,
//       session: OpenAISession {
//         openai: OpenAI {
//           baseURL: "https://api.openai.com/v1",
//           maxRetries: 10,
//           timeout: 60000,
//           httpAgent: undefined,
//           fetch: [Function: fetch],
//           completions: [Completions],
//           chat: [Chat],
//           embeddings: [Embeddings],
//           files: [Files],
//           images: [Images],
//           audio: [Audio],
//           moderations: [Moderations],
//           models: [Models],
//           fineTuning: [FineTuning],
//           beta: [Beta],
//           _options: [Object],
// ...

// %%
const queryEngine = index.asQueryEngine()

// %%
console.log(queryEngine)
// Out:
// RetrieverQueryEngine {
//   retriever: VectorIndexRetriever {
//     index: VectorStoreIndex {
//       serviceContext: {
//         llm: OpenAI {
//           apiKey: undefined,
//           model: "gpt-3.5-turbo",
//           temperature: 0.1,
//           topP: 1,
//           maxTokens: undefined,
//           maxRetries: 10,
//           timeout: 60000,
//           additionalChatOptions: undefined,
//           additionalSessionOptions: undefined,
//           session: [OpenAISession],
//           callbackManager: undefined
//         },
//         embedModel: OpenAIEmbedding {
//           apiKey: undefined,
//           model: "text-embedding-ada-002",
//           dimensions: undefined,
//           maxRetries: 10,
//           timeout: 60000,
//           additionalSessionOptions: undefined,
//           session: [OpenAISession]
//         },
//         nodeParser: SimpleNodeParser {
//           textSplitter: [SentenceSplitter],
//           includeMetadata: true,
// ...

// %%
const response = await queryEngine.query(
    {
        query: "What did the athior do in college?"
    }
)

// %%
console.log(response['response'])
// Out:
// The author attended college in Russia, where he initially chose a college that gave Macbooks to students. However, he started slacking off, skipping lectures, and feeling like a failure. He eventually lost motivation for attending lectures and doing exercises, leading him to stop going to college and not show up for midterm exams. He returned his Macbook and only went back to pick up his papers five years later.

// %%
import * as llamaIndex from "npm:llamaindex@0.1.8"
const OPENAI_API_KEY=
const apiKey=

// %%
let customLLM = new llamaIndex.OpenAI()
let customEmbedding = new llamaIndex.OpenAIEmbedding()

// %%
console.log(customLLM)
//console.log(customEmbedding)
// Out:
// OpenAI {
//   apiKey: undefined,
//   model: "gpt-3.5-turbo",
//   temperature: 0.1,
//   topP: 1,
//   maxTokens: undefined,
//   maxRetries: 10,
//   timeout: 60000,
//   additionalChatOptions: undefined,
//   additionalSessionOptions: undefined,
//   session: OpenAISession {
//     openai: <ref *1> OpenAI {
//       baseURL: "https://api.openai.com/v1",
//       maxRetries: 10,
//       timeout: 60000,
//       httpAgent: undefined,
//       fetch: [Function: fetch],
//       completions: Completions { _client: [Circular *1] },
//       chat: Chat {
//         _client: [Circular *1],
//         completions: Completions { _client: [Circular *1] }
//       },
//       embeddings: Embeddings { _client: [Circular *1] },
//       files: Files { _client: [Circular *1] },
//       images: Images { _client: [Circular *1] },
//       audio: Audio {
//         _client: [Circular *1],
//         transcriptions: Transcriptions { _client: [Circular *1] },
// ...

// %%
let customServiceContext = new llamaIndex.serviceContextFromDefaults(
    {
        llm: customLLM,
        embedModel: customEmbedding
    }
)

// %%
let customQaPrompt = function({context = "", query = ""}) {
    return `Context information is below.
        ---------------------
        ${context}
        ---------------------
        Given the context information, answer the query.
        Include a random fact about whales in your answer.\
        The whale fact can come from your training data.
        Query: ${query}
        Answer:`
}

// %%
let customResponseBuilder = new llamaIndex.SimpleResponseBuilder(
    customServiceContext,
    customQaPrompt
)

// %%
let customSynthesizer = new llamaIndex.ResponseSynthesizer(
    {
        responseBuilder: customResponseBuilder,
        serviceContext: customServiceContext
    }
)

// %%
let customRetriver = new llamaIndex.VectorIndexRetriever(
    {
        index
    }
)

// %%
let customQueryEngine = new llamaIndex.RetrieverQueryEngine(
    customRetriver,
    customSynthesizer
)

// %%
let llmModifiedResponse = await customQueryEngine.query(
    {
        query: "What does the author think of colege?"
    }
)

// %%
console.log(llmModifiedResponse)
// Out:
// Response {
//   metadata: {},
//   response: "The author of the text has a mixed opinion on college. They acknowledge that college can be valuable"... 554 more characters,
//   sourceNodes: [
//     TextNode {
//       id_: "c0d9bbfc-b583-4c20-b892-2fe8398bb024",
//       metadata: {},
//       excludedEmbedMetadataKeys: [],
//       excludedLlmMetadataKeys: [],
//       relationships: {
//         SOURCE: {
//           nodeId: "./data/abramov.txt",
//           metadata: {},
//           hash: "HPM6aKQO4S9cxAZf/SEinz9ZkBg8PvCKV7D6KypcnQk="
//         },
//         PREVIOUS: {
//           nodeId: "b1f5b666-5d68-464e-a45e-8a79cabff671",
//           metadata: {},
//           hash: "SfOgFxgwrwu5FH4XRf3DltHDqkbdE7PTNZ/veWRElWw="
//         },
//         NEXT: {
//           nodeId: "3bcd151e-6738-4f31-9885-bcd0ad55872d",
//           metadata: {},
//           hash: "Le4J/4xFiS50QG3gsn+HM7pPGCpIb9arpFQLRMiGWuU="
//         }
//       },
// ...

// %%
console.log(llmModifiedResponse.response)
// Out:
// The author of the text has a mixed opinion on college. They acknowledge that college can be valuable for some people, but they personally made the decision to drop out because they had a job and could fall back on their family for support. The author also mentions that they overengineered projects and tried out different technologies, indicating a preference for hands-on experience over traditional education.
//
// Random whale fact: Whales are known to communicate with each other using complex vocalizations, often referred to as whale songs. These songs can vary between different whale species and are used for purposes such as mating and navigation.
